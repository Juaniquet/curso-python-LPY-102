# %% [markdown]
# # 🧪 Módulo 2 — Introducción práctica a Testing con Pytest
#
# En este notebook aprenderás:
# - Qué es `pytest` y por qué se usa.
# - Cómo escribir tests básicos y avanzados.
# - Cómo ejecutar tests desde un notebook usando `!pytest`.
# - Cómo utilizar asserts y tests parametrizados.
#
# Este módulo es clave para el desarrollo profesional en Python.

# %% [markdown]
# ---
# ## 1️⃣ ¿Qué es Pytest?
#
# `pytest` es el framework de testing más usado en Python porque:
# - Es muy simple de usar.
# - No requiere clases ni boilerplate.
# - Detecta automáticamente los archivos `test_*.py` o `*_test.py`.
# - Tiene herramientas avanzadas como fixtures y parametrización.
#
# Ejecutar pytest:
# ```bash
# pytest
# ```

# %% [markdown]
# ---
# ## 2️⃣ Primer ejemplo de test
#
# Vamos a crear un archivo Python con una función sencilla y un test asociado.
#
# ### 📄 Crear módulo `operaciones.py`

# %%
# %%writefile operaciones.py
def sumar(a, b):
    return a + b

def dividir(a, b):
    if b == 0:
        raise ValueError("No se puede dividir por cero")
    return a / b

print("operaciones.py creado")
# Out:
# Overwriting operaciones.py

# %% [markdown]
# ### 📄 Crear archivo de test `test_operaciones.py`

# %%
# %%writefile test_operaciones.py
from operaciones import sumar, dividir
import pytest

def test_sumar():
    assert sumar(2, 3) == 5
    assert sumar(-1, 1) == 0

def text suma_cadenas():
    with pytest.raises()
        sumar("hola","mundo")

def test_dividir():
    assert dividir(10, 2) == 5

def test_dividir_cero():
    with pytest.raises(ValueError):
        dividir(10, 0)

print("test_operaciones.py creado")
# Out:
# Overwriting test_operaciones.py

# %% [markdown]
# ### ▶️ Ejecutar los tests desde el notebook
# Puedes ejecutar pytest con:

# %%
# !pytest -q
# Out:
# =================================== ERRORS ====================================
# ____________________ ERROR collecting test_operaciones.py _____________________
# ..\..\..\AppData\Local\anaconda3\lib\site-packages\_pytest\python.py:608: in _importtestmodule
#     mod = import_path(self.path, mode=importmode, root=self.config.rootpath)
# ..\..\..\AppData\Local\anaconda3\lib\site-packages\_pytest\pathlib.py:533: in import_path
#     importlib.import_module(module_name)
# ..\..\..\AppData\Local\anaconda3\lib\importlib\__init__.py:126: in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
# <frozen importlib._bootstrap>:1050: in _gcd_import
#     ???
# <frozen importlib._bootstrap>:1027: in _find_and_load
#     ???
# <frozen importlib._bootstrap>:1006: in _find_and_load_unlocked
#     ???
# <frozen importlib._bootstrap>:688: in _load_unlocked
#     ???
# ..\..\..\AppData\Local\anaconda3\lib\site-packages\_pytest\assertion\rewrite.py:159: in exec_module
#     source_stat, co = _rewrite_test(fn, self.config)
# ..\..\..\AppData\Local\anaconda3\lib\site-packages\_pytest\assertion\rewrite.py:359: in _rewrite_test
#     tree = ast.parse(source, filename=strfn)
# ..\..\..\AppData\Local\anaconda3\lib\ast.py:50: in parse
#     return compile(source, filename, mode, flags,
# E     File "c:\Users\jmjuaniquet\Python\notebooks\modulo2_testing_debug_logging\test_operaciones.py", line 8
# E       def text suma_cadenas():
# E                ^^^^^^^^^^^^
# E   SyntaxError: invalid syntax
# =========================== short test summary info ===========================
# ERROR test_operaciones.py
# !!!!!!!!!!!!!!!!!!! Interrupted: 1 error during collection !!!!!!!!!!!!!!!!!!!!
# 1 error in 0.83s

# %% [markdown]
# ---
# ## 3️⃣ Tests parametrizados
#
# `pytest.mark.parametrize` permite probar múltiples casos sin repetir código.
#
# ### Ejemplo:

# %%
# %%writefile test_parametrizado.py
import pytest
from operaciones import sumar

@pytest.mark.parametrize("a,b,resultado", [
    (1, 1, 2),
    (2, 3, 5),
    (-5, 5, 0)
])
def test_sumar_parametrizado(a, b, resultado):
    assert sumar(a, b) == resultado

print("test_parametrizado.py creado")
# Out:
# Writing test_parametrizado.py

# %%
# !pytest -q
# Out:
# =================================== ERRORS ====================================
# ____________________ ERROR collecting test_operaciones.py _____________________
# ..\..\..\AppData\Local\anaconda3\lib\site-packages\_pytest\python.py:608: in _importtestmodule
#     mod = import_path(self.path, mode=importmode, root=self.config.rootpath)
# ..\..\..\AppData\Local\anaconda3\lib\site-packages\_pytest\pathlib.py:533: in import_path
#     importlib.import_module(module_name)
# ..\..\..\AppData\Local\anaconda3\lib\importlib\__init__.py:126: in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
# <frozen importlib._bootstrap>:1050: in _gcd_import
#     ???
# <frozen importlib._bootstrap>:1027: in _find_and_load
#     ???
# <frozen importlib._bootstrap>:1006: in _find_and_load_unlocked
#     ???
# <frozen importlib._bootstrap>:688: in _load_unlocked
#     ???
# ..\..\..\AppData\Local\anaconda3\lib\site-packages\_pytest\assertion\rewrite.py:159: in exec_module
#     source_stat, co = _rewrite_test(fn, self.config)
# ..\..\..\AppData\Local\anaconda3\lib\site-packages\_pytest\assertion\rewrite.py:359: in _rewrite_test
#     tree = ast.parse(source, filename=strfn)
# ..\..\..\AppData\Local\anaconda3\lib\ast.py:50: in parse
#     return compile(source, filename, mode, flags,
# E     File "c:\Users\jmjuaniquet\Python\notebooks\modulo2_testing_debug_logging\test_operaciones.py", line 8
# E       def text suma_cadenas():
# E                ^^^^^^^^^^^^
# E   SyntaxError: invalid syntax
# =========================== short test summary info ===========================
# ERROR test_operaciones.py
# !!!!!!!!!!!!!!!!!!! Interrupted: 1 error during collection !!!!!!!!!!!!!!!!!!!!
# 1 error in 0.87s

# %%
#%%writefile utilidades.py
def es_par(n):
    return n % 2 == 0


es_par(23452)
# Out:
# True

# %% [markdown]
# ---
# ## 4️⃣ Ejercicio práctico
#
# ### 🧩 Ejercicio
# Crea una función:
# ```python
# def es_par(n):
#     # devuelve True si n es par
# ```
#
# Y un test con casos:
# - 0
# - 2
# - 5
# - 100
#
# Usa parametrización.

# %%
# %%writefile test_utilidades.py
import pytest
from utilidades import es_par

@pytest.mark.parametrize("n, esperado", [
    (0, True),
    (2, True),
    (5, False),
    (100, True)
])
def test_es_par(n, esperado):
    assert es_par(n) == esperado
# Out:
# Overwriting test_utilidades.py

# %% [markdown]
# ---
# ## ✅ Solución (oculta)
#
# <details>
# <summary>Mostrar solución</summary>
#
# ```python
# %%writefile utilidades.py
# def es_par(n):
#     return n % 2 == 0
# ```
#
# ```python
# %%writefile test_utilidades.py
# import pytest
# from utilidades import es_par
#
# @pytest.mark.parametrize("n, esperado", [
#     (0, True),
#     (2, True),
#     (5, False),
#     (100, True)
# ])
# def test_es_par(n, esperado):
#     assert es_par(n) == esperado
# ```
# </details>
